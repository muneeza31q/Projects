# %%
import csv
import sqlite3
import pandas as pd

# Connecting to the geeks database
connection = sqlite3.connect('pubmed_crawler.db')
 
# Creating a cursor object to execute
# SQL queries on a database table
cursor = connection.cursor()
 
# Table Definition
create_table = '''CREATE TABLE covid_info(
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                Title TEXT NOT NULL,
                Abstract TEXT NOT NULL,
                Author_List TEXT NOT NULL,
                Publication_Date TEXT NOT NULL);
                '''
 
# Creating the table into our database
cursor.execute(create_table)
 
# Opening the csv file
file = open('covid.csv')
 
# Reading the contents of the
# covid.csv file
contents = csv.reader(file)
 
# SQL query to insert data into the
# info table
insert_records = "INSERT INTO covid_info (Title, Abstract, Author_List, Publication_Date) VALUES(?, ?, ?, ?);"

# Importing the contents of the file
# into our info2 table
cursor.executemany(insert_records, contents)
 
# SQL query to retrieve all data from
# the person table To verify that the
# data of the csv file has been successfully
# inserted into the table
#select_all = "SELECT * FROM info1;"
#select_all2 = "SELECT * FROM info66 ORDER BY Author_List ASC;"
select_all= "SELECT Author_List, Title FROM covid_info WHERE Author_List LIKE '%Goyal, Deepika%';"
rows = cursor.execute(select_all).fetchall()
#rows2 = cursor.execute(select_all2).fetchall() 
#rows3 = cursor.execute(select_all3).fetchall()

# Output to the console screen
for r in rows:
        print(r)
#for r2 in rows2:
#        print(r2)
#for r3 in rows3:
#        print(r3)
# Committing the changes
connection.commit()
 
# closing the database connection
connection.close()

# %%
import csv
import sqlite3
 
# Connecting to the geeks database
connection = sqlite3.connect('pubmed_crawler.db')
 
# Creating a cursor object to execute
# SQL queries on a database table
cursor = connection.cursor()
 
# Opening the csv file
file = open('covid.csv')
 
# Reading the contents of the
# person-records.csv file
contents = csv.reader(file)
 
# SQL query to insert data into the
# info table
insert_records = "INSERT INTO info52 (Title, Abstract, Author_List, Publication_Date) VALUES(?, ?, ?, ?);"
select_all3= "SELECT Author_List FROM info52 WHERE Author_List = 'Godwin' ;"
rows3 = cursor.execute(select_all3).fetchall()
for r3 in rows3:
    print(r3)
;
 
connection.commit()
 
# closing the database connection
connection.close()

# %%
# impot packages
# install packages if not loaded 
# pip install sqlite3
import csv
import sqlite3
import pandas as pd

# Connecting to the geeks database
connection = sqlite3.connect("pubmed_crawler.db")
# Creating a cursor object to execute
# SQL queries on a database table
cursor = connection.cursor()
# Table Definition
create_table = """CREATE TABLE covid_info1(
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                Title TEXT NOT NULL,
                Abstract TEXT NOT NULL,
                Author_List TEXT NOT NULL,
                Publication_Date TEXT NOT NULL);
                """
# Creating the table into our database
cursor.execute(create_table)

# Opening the csv file
file = open("covid.csv")
# Reading the contents of the
# covid.csv file
contents = csv.reader(file)
# SQL query to insert data into the
# info table
insert_records = "INSERT INTO covid_info1 (Title, Abstract, Author_List, Publication_Date) VALUES(?, ?, ?, ?);"
# Importing the contents of the file
# into our info2 table
cursor.executemany(insert_records, contents)

# SQL query to retrieve all data from
# the person table To verify that the
# data of the csv file has been successfully
# inserted into the table
# select_all = "SELECT * FROM info1;"
# select_all2 = "SELECT * FROM info66 ORDER BY Author_List ASC;"
select_all = (
    "SELECT Author_List, Title FROM covid_info1 WHERE Author_List LIKE '%Goyal, Deepika%';"
)
rows = cursor.execute(select_all).fetchall()
# rows2 = cursor.execute(select_all2).fetchall()
# rows3 = cursor.execute(select_all3).fetchall()

# Output to the console screen
for r in rows:
    print(r)
# for r2 in rows2:
#        print(r2)
# for r3 in rows3:
#        print(r3)
# Committing the changes
connection.commit()
# closing the database connection
connection.close()
